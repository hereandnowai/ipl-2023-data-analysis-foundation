# %% [markdown]
# # Customer Segmentation (K-Means from Scratch)
#
# ## SECTION 1: Problem Statement
# Group mall customers based on their **Annual Income** and **Spending Score** to target marketing campaigns.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Load dataset
df = pd.read_csv('mall_customers.csv')
X = df[['Annual Income (k$)', 'Spending Score (1-100)']].values

# Simple K-Means from scratch (single iteration demonstration for beginners)
k = 5
# Randomly initialize centroids
centroids = X[np.random.choice(X.shape[0], k, replace=False)]

def assign_clusters(X, centroids):
    distances = np.sqrt(((X[:, np.newaxis] - centroids)**2).sum(axis=2))
    return np.argmin(distances, axis=1)

clusters = assign_clusters(X, centroids)

# Plotting the segmented customers
plt.figure(figsize=(10, 8))
for i in range(k):
    plt.scatter(X[clusters == i, 0], X[clusters == i, 1], label=f'Cluster {i+1}')

plt.scatter(centroids[:, 0], centroids[:, 1], s=300, c='black', marker='X', label='Centroids')
plt.xlabel('Annual Income')
plt.ylabel('Spending Score')
plt.title('Customer Segments')
plt.legend()
plt.show()
